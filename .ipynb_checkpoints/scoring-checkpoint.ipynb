# %%
import os, itertools, subprocess, json, struct, math
import random
from time import time
from glob import glob

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc, precision_score, recall_score, f1_score

plt.rcParams.update({'font.size': 28})

# %%
BASE_PATH = '/home/bosco/CracklingPlusPlus/build/'

EXTRACTOR = BASE_PATH + 'ExtractOfftargets/ExtractOfftargets'
# ExtractOfftargets <output-file>  {<input-file-1> <input-file-2> ... <input-file-n> | <input-dir>}

INDEXER = BASE_PATH + 'ISSLCreateIndex/ISSLCreateIndex'
# ISSLCreateIndex <offtarget-sites> <slice-config> <sequence-length> <output-file>

SCORER = BASE_PATH + 'ISSLScoreOfftargetsMMF/ISSLScoreOfftargetsMMF'
# ISSLScoreOfftargetsMMF [issltable] [query file] [max distance] [score-threshold] [score-method]

GENOMES = '/mnt/ssd1/genomes/ncbi_dataset/data'

ASSEMBLY_DATA = '/mnt/ssd1/genomes/ncbi_dataset/data/assembly_data_report.jsonl'

# DATA = '/mnt/hdd2/jake/issl-approximate-coverage'
DATA = 'test_data'

# genomes = [
#     ('O_sativa', 'GCF_001433935.1'),
#     ('P_hallii', 'GCF_002211085.1'),
#     ('X_couchianus', 'GCF_001444195.1'),
#     ('P_major', 'GCF_001522545.3'),
#     ('C_viridis', 'GCA_003400415.2'),
#     ('D_rerio', 'GCF_000002035.6'),
#     ('O_mykiss', 'GCF_002163495.1'),
#     ('M_musculus', 'GCF_000001635.24'),
#     ('M_domestica', 'GCF_000002295.2'),
#     ('T_urartu', 'GCA_003073215.1'),
#     #('R_bivittatum', 'GCF_901001135.1'),
#     #('T_turgidum', 'GCA_900231445.1')
# ]

genomes = [
    ('E_coli', 'GCA_000010385.1'),
    ('X_couchianus', 'GCF_001444195.1')
    # ('C_viridis', 'GCA_003400415.2')
]

CLASS_COLOURS = {
    'tp': '#2E8B57',      # sea green — strong, clear green
    'tn': '#66C2A5',      # light green — complements TP
    'fp': '#D55E00',      # orange-red — colour-blind safe error tone
    'fn': '#E69F00',      # amber — pairs with FP
}

# %%
INDEXER
# Out:
# '/home/bosco/CracklingPlusPlus/build/ISSLCreateIndex/ISSLCreateIndex'

# %% [markdown]
# # Extract Offtargets

# %%
for genome in genomes:
    species = genome[0]
    accession = genome[1]

    genome_index = os.path.join(DATA, 'genomes', accession, f"{os.path.basename(species)}.fna")
    off_target_index = os.path.join(DATA, 'offtargets', accession, f"{os.path.basename(accession)}_offTargets.txt")
    
    skip = os.path.exists(off_target_index)
    
    if not skip:
        print('✅' if skip else '▶', accession, species, genome_index, off_target_index, sep='\t')

    if skip:
        continue

    subprocess.run([
        EXTRACTOR,
        off_target_index,
        genome_index
    ], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

        
print('Done.')
# Out:
# Done.

# %% [markdown]
# # Off-target lists

# %%
offtarget_lists = {
    g[1] : glob(f"test_data/offtargets/{g[1]}/*_offTargets.txt")[0]
    for g in genomes
}
offtarget_lists
# Out:
# {'GCA_000010385.1': 'test_data/offtargets/GCA_000010385.1/GCA_000010385.1_offTargets.txt',
#  'GCF_001444195.1': 'test_data/offtargets/GCF_001444195.1/GCF_001444195.1_offTargets.txt'}

# %% [markdown]
# # Off-target counts
#
# After the indexes are built, the *unique off-target count* is extracted from the index metadata. See a cell further below.

# %%
offtarget_counts = {
    g[1] : os.path.getsize(offtarget_lists[g[1]]) / 21
    for g in genomes
}
offtarget_counts
# Out:
# {'GCA_000010385.1': 860096.0, 'GCF_001444195.1': 101069949.0}

# %% [markdown]
# # Build indexes

# %%
# ISSLCreateIndex <offtarget-sites> <slice-config> <sequence-length> <output-file>

for genome in genomes:
    species = genome[0]
    accession = genome[1]
    offtargets = offtarget_lists[accession]

    for maskset in sorted(glob(f"masksubsets/*.txt")):
        
        # if not any([x in maskset for x in [f'8-28-{x:0>2}' for x in range(4,13)]]):
        #     continue
        
        index = os.path.join(DATA, 'indexes', accession, f"{os.path.basename(maskset).replace('.txt', '')}.issl")
        
        skip = os.path.exists(index)
        
        if not skip:
            print('✅' if skip else '▶', accession, species, offtargets, maskset, index, sep='\t')
    
        if skip:
            continue
    
        subprocess.run([
            INDEXER,
            offtargets,
            maskset,
            '20',
            index
        ], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

        # subprocess.run([
        #     INDEXER,
        #     offtargets,
        #     maskset,
        #     '20',
        #     index
        # ])

        
print('Done.')
# Out:
# Done.

# %% [markdown]
# # Unique off-target counts
#
# This is stored in the first 8 bytes of the ISSL index.
#
# Using any index of a genome would be fine but I will use the full maskset (not a subset).

# %%
offtarget_uniq_counts = {}
for genome in genomes:
    species = genome[0]
    accession = genome[1]
    
    index = os.path.join(DATA, 'indexes', accession, f"slice-8-20.issl")
    skip = not os.path.exists(index)
    
    print('❌' if skip else '✅', accession, species, sep='\t')
    
    if skip:
        offtarget_uniq_counts[accession] = None
        continue

    with open(index, 'rb') as fp:
        data = fp.read(8)  # read 8 bytes (sizeof(uint64_t))
        offtargets_count = struct.unpack("<Q", data)[0]  # little-endian uint64_t
        offtarget_uniq_counts[accession] = int(offtargets_count)
        
offtarget_uniq_counts
# Out:
# ✅	GCA_000010385.1	E_coli
# ✅	GCF_001444195.1	X_couchianus
# {'GCA_000010385.1': 834915, 'GCF_001444195.1': 89119846}

# %% [markdown]
# # Index sizes

# %%
index_sizes = {}

for genome in genomes:
    species = genome[0]
    accession = genome[1]
    
    index_sizes[accession] = {}
    
    for index in glob(os.path.join(DATA, 'indexes', accession, '*.issl')):
        index_shortname = os.path.basename(index).replace('.issl', '').replace('slice-', '')
        
        index_sizes[accession][index_shortname] = os.path.getsize(index)
        
(pd.DataFrame.from_dict(index_sizes, orient='index').sort_index(axis=1) / 1024 / 1024 / 1024).round(2).T # gigabytes
#index_sizes
# Out:
#                GCA_000010385.1  GCF_001444195.1
# 8-20                      0.14            13.95
# testmask-4-20             0.03             3.32
# testmask-6-20             0.04             4.65

# %% [markdown]
# # List of guides

# %% [markdown]
# The existing lists contained the PAM but we need lists without the PAM.
#
# I used this bash script to adjust:
#
#     - Ran from the directory `/mnt/ssd1/jake/issl-approximate-coverage/guides`
#
# ```bash
# for i in *_candidates_23_10k_*.fa; do
#     [[ -f "$i" ]] || continue
#     out="${i/_candidates_23_10k_/_candidates_20_10k_}"
#     echo "Trimming $i -> $out"
#     cut -c1-20 "$i" > "$out"
# done
# ```

# %%
guides = [
'AAAGATGATACAGACAGGAT',
  'AACCCCACAGCGCTACTATC',
  'AACCTTATATTCATCTTCAG',
  'AAGACCTTCAGCGTAAGACG',
  'AAGCCCGTAATTATGACCTT',
  'AAGGTCGGACCATTCCTGGT',
  'AAGTATCTGTCACGTGATGT',
  'AATCGTAAATAGCACCAAGT',
  'ACACACCTCCCTCTACGCTG',
  'ACACGCGACGAGGCGTGAGA',
  'ACACGGCGTATAACTTCGCA',
  'ACATGGTCCGGTAATTAGAC',
  'ACCAACCCAGTTTCGCGGCA',
  'ACCGGTGACCAAAAGGCAGG',
  'ACCTAGAACGTAAGGTGACT',
  'ACCTTTGGCAGAAGGACGCC',
  'ACGAACAGGTGCAGTTGGAG',
  'ACGCCCAGGAGCTTACGGCC',
  'ACGCGCATAGAACGCTCATG',
  'ACGTCGTTGTCCTCACTTTG',
  'ACTAAAGGTCATCATACTGT',
  'ACTATCCAGCTGCACAAGAC',
  'ACTCATGCTGACTAGCTGAA',
  'ACTGAAAATGTTAGCTCCAC',
  'ACTGGTCGCTGTAGCCGTTT',
  'AGAACGCGGGCGGAAGCTAC',
  'AGAGTTGTTCTTCGGTGGCA',
  'AGAGTTTGATCCCGAGCCTA',
  'AGCTATGAAGTGACCTTTAA',
  'AGCTCTTGTGACTATAATAG',
  'AGGACTACGAAGACGTCGGA',
  'AGGTGGTTAGGGTGTCTCTT',
  'AGTAATCCTTGATCTACCGG',
  'AGTCATGGAATGTTAACTGA',
  'AGTCTGACTTTTGGTGCCTA',
  'AGTGACGGCTAGTGTGCGAG',
  'AGTGTGGTTCAACATGTGTA',
  'AGTTTGACTATGAGGCCTGC',
  'ATATAGTCAAGCAGTCGAGG',
  'ATATGACGCTCAGAGTGCAA',
  'ATCAGCCTGAGAGGCCGCTG',
  'ATCCCAGCCAATCAAGCCTG',
  'ATCCCCCTGTCGATAATCAA',
  'ATCTCGACGCTTCCCCCCTA',
  'ATGCAATAGGAGCGTTCCCC',
  'ATGCCGACTTCGTTCTCTTC',
  'ATGCTCCGACCACAGAGATT',
  'ATGGCATGCCTGTACCCGGA',
  'ATGGTATTGAAGTCGTACAC',
  'ATGGTCTTACGTAGGATAGC',
  'ATGTCGTAGGTCACCGTCCG',
  'ATTAGGCTCGGTGAACCGGC',
  'ATTTCTGTTTCTATTAAAAG',
  'ATTTTGTTAAAGGAGGTAGC',
  'CAAGTTCTTTAGCGCCGTCA',
  'CAATCGATACTGTGGTTTTT',
  'CAATCTTGGCGACAGCAATC',
  'CACCGCGCTGCGGAAAGCAT',
  'CACGTAGAAAGCCGCGACAT',
  'CACTCCCGGACTCGTAGTCC',
  'CAGACTACCAGACTATCTTC',
  'CAGAGCAATCAACCTTATCT',
  'CAGAGCTCGCCTCGCGCTCT',
  'CAGCTAGAACCCCTATTTAA',
  'CAGCTATCAACTTATGTGAC',
  'CAGTATACGGTGTGCAGCCT',
  'CAGTTATCACGGATTACCCA',
  'CATAACCAGCGAGGCAGTAC',
  'CATACGTCGGAATAGCCGCC',
  'CATAGCGGCATTAGCGGAGT',
  'CATCAACAGATAAACATCAT',
  'CATTTATTTTCTCAAACTAA',
  'CCAGAGGATTGTTATATCAA',
  'CCATCCATTTGATCATGGAA',
  'CCCACGCTTGAACATGATAG',
  'CCCCACCCTAGCTGATATGG',
  'CCGCGTGCCGAGGTAGCAGA',
  'CCGTGATCCAAGACATCGTT',
  'CCTCCGATATGACATTACAG',
  'CCTGATGGCTGTGGCGCATA',
  'CCTGTTAATCAGAGTAGATC',
  'CCTGTTATTAAGCTGGCCTC',
  'CCTTGCTTTTAGCCATTTGG',
  'CCTTTCGAATCGAACCGAGC',
  'CGATTAAAGCACCAAAGATG',
  'CGCAGAAGATCAACTTGGCC',
  'CGCATATTTAAACCCCCTTA',
  'CGGCCAACTGCGACGGGGGG',
  'CGGGACTAGCTCTACATATG',
  'CGGTGGTAGATTGTAATGTT',
  'CGTATCGGGCGTCTCGAAAA',
  'CGTCCCCGACCAGGTGGCTA',
  'CGTTAGAGTAGGACCGGTCG',
  'CTAAAATTGTGGGTGTCTAC',
  'CTAGTGGTGGGTGTTTTTTC',
  'CTATTAACAACTTGGCGGGT',
  'CTCCGTGAAGCTGTAAAGCA',
  'CTCCGTGATTGGGATTCATT',
  'CTCGGTACACCGATACTGAC',
  'CTCGTAAATGAGCTGGGTTG',
  'CTGCTATTGTTCTTTCCCTC',
  'CTGGACTGCAGGGTCATAAC',
  'CTTAAGTGTCGGGGGCCGTG',
  'CTTAATTGCCAATCCAATCG',
  'CTTAGGGCAGTTACCCTCTG',
  'CTTTCCCGTGTGCCCACCTT',
  'GAAACGTCGAGCCAGACGCC',
  'GAACTACGGACGTTCCCCTC',
  'GAAGCTTAATCTTGCAGTGC',
  'GACAAGATCAAGCAATATAT',
  'GACACCTGGGACTGAGGAAA',
  'GACCGCGCGGTAAAAGTAAT',
  'GAGAGATCCTTTAGCGGCTC',
  'GATGATTTGCGGGTCATATC',
  'GATTCCCCATCCTAACATCG',
  'GATTGATGATTTTGAGCGCC',
  'GCACTGACGGGCACCTCCTG',
  'GCACTTCCTTCGGGACGTGG',
  'GCCCAAATGACTGCGTCAGG',
  'GCCCAGCATTTCTACAAATT',
  'GCCCTGGGAAGTCTGGCAAA',
  'GCGTGTGTCGGATAGCACCA',
  'GCTTCGTCCTCTTCTGCTTG',
  'GGACCTATTGTTACGCCACC',
  'GGATATAATTATTGATGAAC',
  'GGATATCTGTTTGTGACAAC',
  'GGATGCGAGTCGGGGAAGTC',
  'GGCACGCACCGTTGACCGAG',
  'GGCTCATCCTGACTATCTGT',
  'GGCTGACCCAGGAGTGTCAA',
  'GGGAACATTTCGAGTTCCCT',
  'GGGATACTAATCTCGACGTT',
  'GGGCTCTGTGCATAAAAGGT',
  'GGGGAGCCGGAGTACGTCTG',
  'GTAAAACGCACGTTGCATAA',
  'GTACATCAAAGGAACGCTCC',
  'GTAGGGTCACATGGCCGGAG',
  'GTAGTCTGACAATACACCGA',
  'GTCGTACGTAAGAAAAGCCC',
  'GTCTGGACAAGCATTTAGCA',
  'GTGAGTTTGGTTCGTGGCGT',
  'GTGCAGTGTAAAAGCGCCCA',
  'GTGCATGTCGTCATGGACAT',
  'GTGGTGCATAGGTTGAATAA',
  'GTTCATCAAAGAGCATAACA',
  'GTTCCCCTGGGAAGTATCTC',
  'TAAGCGCCTAAGCTCCTTTA',
  'TAAGGAACAGAGCTACTAGC',
  'TACATAGCGGATACGGATTT',
  'TACGACAGTATGGGTGAACG',
  'TACGTGCGGTTTGGGCCGTA',
  'TACTGGTATCTTTGCCTCCG',
  'TAGAGCGAGCTGTGTTGAGT',
  'TAGCCCTTTACAAAATTGAG',
  'TAGCGCAAGTCGTGAACGTC',
  'TATGATCAATTCGAATTTAT',
  'TATGTGCGAACTAGATCCCA',
  'TATTAACTGAGTAGCCTCGG',
  'TATTCATCCTGGTAAATGGG',
  'TCAAAGTTCCTACTTACCTT',
  'TCAGCAGCTGTCCACCAATG',
  'TCAGCTTGCCAAGCGGATCT',
  'TCAGTAGTGGAATGAGAGAG',
  'TCAGTGGGGTTGCCCGGAAA',
  'TCATATTCAGACAGAACCAG',
  'TCCACGTGGGCTACGGAAAG',
  'TCCATCCAGGAGGGAACGTT',
  'TCCGATCAGCACACCACCCC',
  'TCCGCCAACGCCGGCCTCTC',
  'TCCGTCCTTGCTTTAGTAAA',
  'TCCTCGGTATAAGCTAATGG',
  'TCGCGTTGCCGGTTATGGCT',
  'TCGCTGGCCATCGTGGTACA',
  'TCTATTTAAAAAATTGTAGT',
  'TCTCAGTCGCTGCAGTCGCT',
  'TCTGGATTTAAACTGCCGGC',
  'TGAACGTGTTGGTTCGGGAC',
  'TGACGGAAGACTATCCAAAA',
  'TGAGCTGCTTAGCAAGGGTA',
  'TGAGTTCACCATCTTCAGAC',
  'TGCAAGAGTCTTTTTATGTT',
  'TGCACCTGTCGGAGTCTGCG',
  'TGCCAATTACCATGATACGC',
  'TGCGTTTCGTCAGGGCGTGA',
  'TGCTCAATCTTAACGCTTGC',
  'TGGAGACCAAGTGGTCCTGA',
  'TGGCTTTGCCATCAAGAGCA',
  'TGGGAAGAACCAATACAGAC',
  'TGGTAAGTACTCTGAATGTC',
  'TGTAACGAGAGATTATACTA',
  'TTAACGTACACAAGTAGCTC',
  'TTACCCGCGCTCACATTCAT',
  'TTCCGGTCACCTTAACTTCG',
  'TTCTATTGAGCGGAATGGGG',
  'TTGACTTAGTCACTTCCTGC',
  'TTGCATAAAGAGAGTCCTGT',
  'TTGCTATTTGCTACAATTCG',
  'TTTCGAAAGCGATTCTTCCA',
  'TTTCGAAGATAAACTTAGTT',
  'TTTTAGGGGGTGGGCTAGGC'
]

with open("guides.txt", "w", newline="\n") as f:
    for g in guides:
        f.write(g + "\n")

# %%
with open("test_data/guides/issl-E_coli_candidates_10k_01_noPAM.stdout", "r") as infile, open("test_data/guides/guides.txt", "w") as outfile:
    for line in infile:
        guide = line.split()[0]   # first whitespace-separated field
        outfile.write(guide + "\n")

# %%
guide_file = pd.read_csv(os.path.join(DATA, "guides/df_candidates.csv"))
print(guide_file.head)
# Out:
# <bound method NDFrame.head of                           seq_ref                      seq_alt  mismatches  \
# 0     ATGCAAACCACAACACTGTCTTCTTTG  ATACCAACCACAACAGTGTCTACTTTC           4
# 1     ATGCAAACCACAACACTGTCTTCTTTG  ATTCAAACCACAACACTGTCTTCTTTG           1
# 2     ATGCAAACCACAACACTGTCTTCTTTG  ATGCAAACCACAACACTGTCTTCTTTG           0
# 3     ATGCAAACCACAACACTGTCTTCTTTG  ATACGAACTACAACACTGTCTACTTTC           4
# 4     GATCAAAGAAGACAGTGTTGTGGTTTG  TGTCAAAGAAGACAGTGTTGTGGTTTG           2
# ...                           ...                          ...         ...
# 3167  ATTATCATCGTTATTTGGCTGAGTTTA  ATTATCATCGGTACATGGCTGAGTTTA           3
# 3168  ACTCCAGGAGCGATCAGATCCGGTTTA  ACTCCAGGAGCAATCACGTCCGGTTTA           3
# 3169  ACTCCAGGAGCGATCAGATCCGGTTTA  ACTCCGGGAGCAATCAAATCCGGTTTA           3
# 3170  ATATCGGTGAAGAGTCCTGGACCTTTG  ATTTCGGTGTAGAGACCGGGACCTTTC           4
# 3171  ATATCGGTGAAGAGTCCTGGACCTTTG  ATTTCAGTGTAGAGTCCTGGACCTTTA           3
#
#       seq_ref_start  seq_alt_start  seq_ref_end  seq_alt_end seq_ref_strand  \
# 0             47251       30277553        47278     30277580              +
# 1             47251         594379        47278       594406              +
# 2             47251         596099        47278       596126              +
# 3             47251         363550        47278       363577              +
# 4             47254         594376        47281       594403              -
# ...             ...            ...          ...          ...            ...
# 3167       26149831        3285837     26149858      3285864              -
# 3168       26872933        4659210     26872960      4659237              +
# 3169       26872933       16657703     26872960     16657730              +
# 3170       26935227          85758     26935254        85785              -
# 3171       26935227        4891357     26935254      4891384              -
#
#      seq_alt_strand                                     seq_ref_header  \
# 0                 +  NC_003070.9 Arabidopsis thaliana chromosome 1 ...
# 1                 -  NC_003070.9 Arabidopsis thaliana chromosome 1 ...
# 2                 -  NC_003070.9 Arabidopsis thaliana chromosome 1 ...
# 3                 +  NC_003070.9 Arabidopsis thaliana chromosome 1 ...
# 4                 +  NC_003070.9 Arabidopsis thaliana chromosome 1 ...
# ...             ...                                                ...
# 3167              -  NC_003076.8 Arabidopsis thaliana chromosome 5,...
# 3168              +  NC_003076.8 Arabidopsis thaliana chromosome 5,...
# 3169              +  NC_003076.8 Arabidopsis thaliana chromosome 5,...
# 3170              -  NC_003076.8 Arabidopsis thaliana chromosome 5,...
# 3171              +  NC_003076.8 Arabidopsis thaliana chromosome 5,...
#
#                                          seq_alt_header seq_ref_chromosome  \
# 0     NC_003070.9 Arabidopsis thaliana chromosome 1 ...        NC_003070.9
# 1     NC_003070.9 Arabidopsis thaliana chromosome 1 ...        NC_003070.9
# 2     NC_003070.9 Arabidopsis thaliana chromosome 1 ...        NC_003070.9
# 3     NC_003074.8 Arabidopsis thaliana chromosome 3,...        NC_003070.9
# 4     NC_003070.9 Arabidopsis thaliana chromosome 1 ...        NC_003070.9
# ...                                                 ...                ...
# 3167  NC_003076.8 Arabidopsis thaliana chromosome 5,...        NC_003076.8
# 3168  NC_003074.8 Arabidopsis thaliana chromosome 3,...        NC_003076.8
# 3169  NC_003075.7 Arabidopsis thaliana chromosome 4,...        NC_003076.8
# 3170  NC_003074.8 Arabidopsis thaliana chromosome 3,...        NC_003076.8
# 3171  NC_003076.8 Arabidopsis thaliana chromosome 5,...        NC_003076.8
#
#      seq_alt_chromosome seq_ref_gene seq_alt_gene
# 0           NC_003070.9    AT1G01080    AT1G80530
# 1           NC_003070.9    AT1G01080        CSLD5
# 2           NC_003070.9    AT1G01080        CSLD5
# 3           NC_003074.8    AT1G01080    AT3G02080
# 4           NC_003070.9    AT1G01080        CSLD5
# ...                 ...          ...          ...
# 3167        NC_003076.8         GRF8         GRF6
# 3168        NC_003074.8        ARA12    AT3G14067
# 3169        NC_003075.7        ARA12         SLP2
# 3170        NC_003074.8    AT5G67490        VDAC1
# 3171        NC_003076.8    AT5G67490        VDAC3
#
# [3172 rows x 15 columns]>

# %%
with open(os.path.join(DATA, "guides/guides.txt"), "r") as infile, open(os.path.join(DATA, "guides/guides.fa"), "w") as outfile:
    for i, line in enumerate(infile):
        seq = line.strip()

        if seq:  # skip empty lines
            outfile.write(f">guide_{i}\n")
            outfile.write(seq + "\n")

# %%
# guide_lists = {
#     g[1] : sorted(list(glob(os.path.join(DATA, 'guides', f'{g[0]}*_20_10k_*.fa'))))
#     for g in genomes
# }

guide_lists = {
    # g[1] : sorted(list(glob(os.path.join(DATA, f'guides.txt'))))
    g[1] : glob(os.path.join(DATA, f'guides/guides.fa'))
    for g in genomes
}

# guide_lists = {
#     # g[1] : sorted(list(glob(os.path.join(DATA, f'guides.txt'))))
#     g[1] : glob(os.path.join(DATA, f'guides/guides.fa'))
#     for g in genomes
# }
print(guide_lists)
# Out:
# {'GCA_000010385.1': ['test_data/guides/guides.fa'], 'GCF_001444195.1': ['test_data/guides/guides.fa']}

# %%
import os

size = os.path.getsize(os.path.join(DATA, "guides/guides.fa"))

print(size)
print(size % 21)
# Out:
# 328923
# 0

# %%
print(accession)
print(guide_lists)
# Out:
# GCF_001444195.1
# {'GCA_000010385.1': ['test_data/guides/guides.fa'], 'GCF_001444195.1': ['test_data/guides/guides.fa']}

# %% [markdown]
# # Score guides

# %%
# SCORER = '/home/carl/CracklingPlusPlus/build/ISSLScoreOfftargetsMMF/ISSLScoreOfftargetsMMF'
# ISSLScoreOfftargetsMMF [issltable] [query file] [max distance] [score-threshold] [score-method]

# score_threshold = ['75', '80', '85', '90', '95', '0']

for genome in genomes:
    species = genome[0]
    accession = genome[1]
    max_distance = '8' # 4 mismatches
    score_threshold = '0' # exact score
    score_method = 'and' # we want both scores to be exact, but if the threshold is zero this can be any valid option

    for query_file in guide_lists[accession]:
    
        for index in sorted(glob(os.path.join(DATA, 'indexes', accession, f"*.issl"))):

            # convert `M_musculus_candidates_20_10k_01.fa` to `20-10k-01`
            # query_file_shortname = os.path.basename(query_file).replace(f"{species}_", '').replace('.fa', '').replace('_', '-')
            query_file_shortname = os.path.join("guides.fa").replace('.fa', '').replace('_', '-')
            
            index_shortname = os.path.basename(index).replace('.issl', '')
            
            # file to capture off-target scores
            scores = os.path.join(DATA, 'scores', accession, f"{index_shortname}_{query_file_shortname}.txt")
            
            # file to capture run-time
            time_file = os.path.join(DATA, 'times', accession, f"{index_shortname}_{query_file_shortname}.txt")
            
            skip = os.path.exists(scores) and os.path.exists(time_file) and os.path.getsize(time_file) > 0
            
            print('✅' if skip else '▶', accession, species, os.path.basename(query_file), os.path.basename(index), scores, sep='\t')

            # if skip:
            #     continue

            start_time = time()
            with open(scores, 'w') as fp:
                subprocess.run([
                    SCORER,
                    index,
                    query_file,
                    max_distance,
                    score_threshold,
                    score_method
                ], 
                    stdout=fp,
                    stderr=subprocess.PIPE,
                    text=True
            )
            run_time = time() - start_time

            # with open(scores, 'w') as fp:
            #     result = subprocess.run([
            #         SCORER,
            #         index,
            #         query_file,
            #         max_distance,
            #         score_threshold,
            #         score_method
            #     ], capture_output=True, text=True)
                
            # print("RETURN CODE:", result.returncode)
            # print("STDOUT:")
            # print(result.stdout[:1000])
            
            # print("STDERR:")
            # print(result.stderr[:1000])
            
            # not my favourite way to record this...
            with open(time_file, "w") as fp:
                fp.write(f"{run_time}")
# Out:
# ✅	GCA_000010385.1	E_coli	guides.fa	slice-8-20.issl	test_data/scores/GCA_000010385.1/slice-8-20_guides.txt
# ✅	GCA_000010385.1	E_coli	guides.fa	testmask-4-20.issl	test_data/scores/GCA_000010385.1/testmask-4-20_guides.txt
# ✅	GCA_000010385.1	E_coli	guides.fa	testmask-6-20.issl	test_data/scores/GCA_000010385.1/testmask-6-20_guides.txt
# ✅	GCF_001444195.1	X_couchianus	guides.fa	slice-8-20.issl	test_data/scores/GCF_001444195.1/slice-8-20_guides.txt
# ✅	GCF_001444195.1	X_couchianus	guides.fa	testmask-4-20.issl	test_data/scores/GCF_001444195.1/testmask-4-20_guides.txt
# ✅	GCF_001444195.1	X_couchianus	guides.fa	testmask-6-20.issl	test_data/scores/GCF_001444195.1/testmask-6-20_guides.txt

# %% [markdown]
# # Analyse results

# %% [markdown]
# ## Determine what "safe" means

# %%
def calc_score(r, col_mit='mit', col_cfd='cfd'):
    return (r[col_mit] + r[col_cfd]) / 2 / 100

def is_safe(r, threshold=75, col_mit='mit', col_cfd='cfd'):
    if isinstance(threshold, str):
        threshold = r[threshold]
    return (r[col_mit] + r[col_cfd]) / 2 > threshold

def is_safe2(r, threshold=75, col_mit='mit', col_cfd='cfd'):
    if isinstance(threshold, str):
        threshold = r[threshold]
    return r[col_mit] > threshold

# %% [markdown]
# ## Load all scores into Pandas

# %%
frames = []

for genome in genomes:
    species = genome[0]
    accession = genome[1]
    guideset_num = 0
    
    for score_file in sorted(glob(os.path.join(DATA, 'scores', accession, '*.txt'))):
        
        # get time file (ie how long this experiment took to run)
        # ... (shivers)
        run_time = None
        time_file = score_file.replace('scores', 'times')
        
        
        # convert `/full/path/slice-8-28-17_candidates-20-10k-01.txt` to `slice-8-28-17_candidates-20-10k-01`
        score_file_shortname = os.path.basename(score_file).replace('.txt', '')
        
        index, guideset = score_file_shortname.split('_')
        
        _, mask_weight, maskset_size = index.split('-')
        masksubset_size = 20
        # _, guideset_num = guideset.split('-')[1]
        guideset_num+= 1
        
        skip = (os.path.getsize(score_file) == 0) & (not os.path.exists(time_file))
        
        print('🛑' if skip else '✅', species, accession, mask_weight, maskset_size, masksubset_size, guideset_num)
        
        if skip:
            continue
        
        with open(time_file, 'r') as fp:
            run_time = float(fp.read())
        
        df = pd.read_csv(score_file, names=['guide', 'mit', 'cfd'], sep='\t')
        
        # df['species'] = species
        # df['accession'] = accession
        # df['mask_weight'] = int(mask_weight)
        # df['maskset_size'] = int(maskset_size)
        # # df['masksubset_size'] = int(masksubset_size)
        # df['guideset_num'] = int(guideset_num)
        # df['run_time'] = float(run_time)
        
        # frames.append(df)
        
        #print(df.head(3).to_markdown(), '\n\n')
        threshold_values = [75, 80, 85, 90, 95, 100]

        for threshold in threshold_values:

            df_threshold = df.copy()

            df_threshold['species'] = species
            df_threshold['accession'] = accession
            df_threshold['mask_weight'] = int(mask_weight)
            df_threshold['maskset_size'] = int(maskset_size)
            df_threshold['masksubset_size'] = int(masksubset_size)
            df_threshold['guideset_num'] = int(guideset_num)
            df_threshold['run_time'] = float(run_time)
            df_threshold['threshold'] = threshold
            df_threshold['is_safe'] = df[['mit', 'cfd']].apply(lambda x: is_safe(x, threshold, 'mit', 'cfd'), axis=1)

            frames.append(df_threshold)
        
df = pd.concat(frames)

threshold_values = [75, 80, 85, 90, 95, 100]

# for threshold in threshold_values:
#     df[f'is_safe_{threshold}'] = df[['mit', 'cfd']].apply(lambda x: is_safe(x, threshold, 'mit', 'cfd'), axis=1)

print('\n\n', df.shape, '\n\n')
print(df.head(5).to_markdown())
print(df.tail(5).to_markdown())
# Out:
# ✅ E_coli GCA_000010385.1 8 20 20 1
# ✅ E_coli GCA_000010385.1 4 20 20 2
# ✅ E_coli GCA_000010385.1 6 20 20 3
# ✅ X_couchianus GCF_001444195.1 8 20 20 1
# ✅ X_couchianus GCF_001444195.1 4 20 20 2
# ✅ X_couchianus GCF_001444195.1 6 20 20 3
#
#
#  (563868, 12)
#
#
# |    | guide                |     mit |     cfd | species   | accession       |   mask_weight |   maskset_size |   masksubset_size |   guideset_num |   run_time |   threshold | is_safe   |
# |---:|:---------------------|--------:|--------:|:----------|:----------------|--------------:|---------------:|------------------:|---------------:|-----------:|------------:|:----------|
# |  0 | AAAAAAAAAACATATTTTGT | 99.9311 | 99.9527 | E_coli    | GCA_000010385.1 |             8 |             20 |                20 |              1 |    0.39977 |          75 | True      |
# |  1 | GGCGGCACAAAAAAAAAAGT | 99.435  | 99.62   | E_coli    | GCA_000010385.1 |             8 |             20 |                20 |              1 |    0.39977 |          75 | True      |
# |  2 | CGGCGGGTGATTTCGGTAAA | 99.3079 | 99.4302 | E_coli    | GCA_000010385.1 |             8 |             20 |                20 |              1 |    0.39977 |          75 | True      |
# |  3 | AAAAAAACGTGGCAAAATTA | 99.7941 | 99.7411 | E_coli    | GCA_000010385.1 |             8 |             20 |                20 |              1 |    0.39977 |          75 | True      |
# |  4 | CGATGAAAAAAAAAACGAAC | 99.7974 | 99.8762 | E_coli    | GCA_000010385.1 |             8 |             20 |                20 |              1 |    0.39977 |          75 | True      |
# |       | guide                |      mit |     cfd | species      | accession       |   mask_weight |   maskset_size |   masksubset_size |   guideset_num |   run_time |   threshold | is_safe   |
# |------:|:---------------------|---------:|--------:|:-------------|:----------------|--------------:|---------------:|------------------:|---------------:|-----------:|------------:|:----------|
# | 15658 | CGCAGAAAAAAAAAAAAAGC |  7.37873 | 22.0969 | X_couchianus | GCF_001444195.1 |             6 |             20 |                20 |              3 |    22.9018 |         100 | False     |
# | 15659 | ACCAACACAAACGCTACAAA | 80.1677  | 88.5274 | X_couchianus | GCF_001444195.1 |             6 |             20 |                20 |              3 |    22.9018 |         100 | False     |
# | 15660 | AAAAAAAAAACGCGCGCTCA | 89.7706  | 90.6169 | X_couchianus | GCF_001444195.1 |             6 |             20 |                20 |              3 |    22.9018 |         100 | False     |
# | 15661 | ACTGGTGGAAAAAAAAAAAA |  3.39973 | 11.8036 | X_couchianus | GCF_001444195.1 |             6 |             20 |                20 |              3 |    22.9018 |         100 | False     |
# | 15662 | AACGCGCGCTCAAACTGGTG | 94.3753  | 96.061  | X_couchianus | GCF_001444195.1 |             6 |             20 |                20 |              3 |    22.9018 |         100 | False     |

# %%
print(df[df["is_safe"] == True])
# Out:
#                       guide        mit        cfd       species  \
# 0      AAAAAAAAAACATATTTTGT  99.931064  99.952697        E_coli
# 1      GGCGGCACAAAAAAAAAAGT  99.435015  99.620001        E_coli
# 2      CGGCGGGTGATTTCGGTAAA  99.307935  99.430215        E_coli
# 3      AAAAAAACGTGGCAAAATTA  99.794147  99.741118        E_coli
# 4      CGATGAAAAAAAAAACGAAC  99.797410  99.876226        E_coli
# ...                     ...        ...        ...           ...
# 15632  AAACCGCCCGTATGGCGCGG  99.666985  99.713514  X_couchianus
# 15643  AAAGCCAGCACCGGGCATTA  95.216505  98.160842  X_couchianus
# 15648  TTGTGCTCGCAACATCCAAA  98.164624  99.489314  X_couchianus
# 15651  GAGCCGGGTAAAGTATCACC  98.506546  99.558323  X_couchianus
# 15662  AACGCGCGCTCAAACTGGTG  94.375252  96.061006  X_couchianus
#
#              accession  mask_weight  maskset_size  masksubset_size  \
# 0      GCA_000010385.1            8            20               20
# 1      GCA_000010385.1            8            20               20
# 2      GCA_000010385.1            8            20               20
# 3      GCA_000010385.1            8            20               20
# 4      GCA_000010385.1            8            20               20
# ...                ...          ...           ...              ...
# 15632  GCF_001444195.1            6            20               20
# 15643  GCF_001444195.1            6            20               20
# 15648  GCF_001444195.1            6            20               20
# 15651  GCF_001444195.1            6            20               20
# 15662  GCF_001444195.1            6            20               20
#
#        guideset_num   run_time  threshold  is_safe
# 0                 1   0.399770         75     True
# 1                 1   0.399770         75     True
# 2                 1   0.399770         75     True
# 3                 1   0.399770         75     True
# 4                 1   0.399770         75     True
# ...             ...        ...        ...      ...
# 15632             3  22.901841         95     True
# 15643             3  22.901841         95     True
# 15648             3  22.901841         95     True
# 15651             3  22.901841         95     True
# 15662             3  22.901841         95     True
#
# [307341 rows x 12 columns]

# %% [markdown]
# ## Prepare labels

# %%
# for plotting
#   This one shows the number of unique target sites (Millions)
acc_label = {
    g[1] : f"{g[0]} {g[1]} ({offtarget_uniq_counts[g[1]] / 1000 / 1000:0.2f} M)" if offtarget_uniq_counts[g[1]] != None else g[1]
    for g in genomes
}
acc_label
# Out:
# {'GCA_000010385.1': 'E_coli GCA_000010385.1 (0.83 M)',
#  'GCF_001444195.1': 'X_couchianus GCF_001444195.1 (89.12 M)'}

# %%
df[df['mask_weight'] == 4]
# Out:
#                       guide         mit         cfd       species  \
# 0      AAAAAAAAAACATATTTTGT  100.000000  100.000000        E_coli
# 1      GGCGGCACAAAAAAAAAAGT   99.510624   99.628724        E_coli
# 2      CGGCGGGTGATTTCGGTAAA   99.716079   99.477315        E_coli
# 3      AAAAAAACGTGGCAAAATTA   99.876972   99.762987        E_coli
# 4      CGATGAAAAAAAAAACGAAC   99.816011   99.967387        E_coli
# ...                     ...         ...         ...           ...
# 15658  CGCAGAAAAAAAAAAAAAGC    6.297820   23.259371  X_couchianus
# 15659  ACCAACACAAACGCTACAAA   80.479220   89.958864  X_couchianus
# 15660  AAAAAAAAAACGCGCGCTCA   92.524133   87.442773  X_couchianus
# 15661  ACTGGTGGAAAAAAAAAAAA    3.092453   11.616298  X_couchianus
# 15662  AACGCGCGCTCAAACTGGTG   95.681001   98.538991  X_couchianus
#
#              accession  mask_weight  maskset_size  masksubset_size  \
# 0      GCA_000010385.1            4            20               20
# 1      GCA_000010385.1            4            20               20
# 2      GCA_000010385.1            4            20               20
# 3      GCA_000010385.1            4            20               20
# 4      GCA_000010385.1            4            20               20
# ...                ...          ...           ...              ...
# 15658  GCF_001444195.1            4            20               20
# 15659  GCF_001444195.1            4            20               20
# 15660  GCF_001444195.1            4            20               20
# 15661  GCF_001444195.1            4            20               20
# 15662  GCF_001444195.1            4            20               20
#
#        guideset_num   run_time  threshold  is_safe
# 0                 2   0.115736         75     True
# 1                 2   0.115736         75     True
# 2                 2   0.115736         75     True
# 3                 2   0.115736         75     True
# 4                 2   0.115736         75     True
# ...             ...        ...        ...      ...
# 15658             2  13.948375        100    False
# 15659             2  13.948375        100    False
# 15660             2  13.948375        100    False
# 15661             2  13.948375        100    False
# 15662             2  13.948375        100    False
#
# [187956 rows x 12 columns]

# %% [markdown]
# ## Using multiple thresholds

# %% [markdown]
# ### Data prep

# %% [markdown]
# #### Build truth

# %%
truth = truth_df = df[df['mask_weight'] == 8]
# or original Crackling++ masks
truth.tail()
# Out:
#                       guide        mit        cfd       species  \
# 15658  CGCAGAAAAAAAAAAAAAGC   4.376356  11.596443  X_couchianus
# 15659  ACCAACACAAACGCTACAAA  73.855248  82.396057  X_couchianus
# 15660  AAAAAAAAAACGCGCGCTCA  87.568348  81.475723  X_couchianus
# 15661  ACTGGTGGAAAAAAAAAAAA   2.787341   9.703857  X_couchianus
# 15662  AACGCGCGCTCAAACTGGTG  94.340968  95.829913  X_couchianus
#
#              accession  mask_weight  maskset_size  masksubset_size  \
# 15658  GCF_001444195.1            8            20               20
# 15659  GCF_001444195.1            8            20               20
# 15660  GCF_001444195.1            8            20               20
# 15661  GCF_001444195.1            8            20               20
# 15662  GCF_001444195.1            8            20               20
#
#        guideset_num   run_time  threshold  is_safe
# 15658             1  28.505509        100    False
# 15659             1  28.505509        100    False
# 15660             1  28.505509        100    False
# 15661             1  28.505509        100    False
# 15662             1  28.505509        100    False

# %%
for (accession, guideset_num), g in df.sort_values(['accession', 'guideset_num', 'mask_weight', 'maskset_size']).groupby(['accession', 'guideset_num']):
    print(g.head())
# Out:
#                   guide        mit        cfd species        accession  \
# 0  AAAAAAAAAACATATTTTGT  99.931064  99.952697  E_coli  GCA_000010385.1
# 1  GGCGGCACAAAAAAAAAAGT  99.435015  99.620001  E_coli  GCA_000010385.1
# 2  CGGCGGGTGATTTCGGTAAA  99.307935  99.430215  E_coli  GCA_000010385.1
# 3  AAAAAAACGTGGCAAAATTA  99.794147  99.741118  E_coli  GCA_000010385.1
# 4  CGATGAAAAAAAAAACGAAC  99.797410  99.876226  E_coli  GCA_000010385.1
#
#    mask_weight  maskset_size  masksubset_size  guideset_num  run_time  \
# 0            8            20               20             1   0.39977
# 1            8            20               20             1   0.39977
# 2            8            20               20             1   0.39977
# 3            8            20               20             1   0.39977
# 4            8            20               20             1   0.39977
#
#    threshold  is_safe
# 0         75     True
# 1         75     True
# 2         75     True
# 3         75     True
# 4         75     True
#                   guide         mit         cfd species        accession  \
# 0  AAAAAAAAAACATATTTTGT  100.000000  100.000000  E_coli  GCA_000010385.1
# 1  GGCGGCACAAAAAAAAAAGT   99.510624   99.628724  E_coli  GCA_000010385.1
# 2  CGGCGGGTGATTTCGGTAAA   99.716079   99.477315  E_coli  GCA_000010385.1
# 3  AAAAAAACGTGGCAAAATTA   99.876972   99.762987  E_coli  GCA_000010385.1
# 4  CGATGAAAAAAAAAACGAAC   99.816011   99.967387  E_coli  GCA_000010385.1
#
#    mask_weight  maskset_size  masksubset_size  guideset_num  run_time  \
# 0            4            20               20             2  0.115736
# 1            4            20               20             2  0.115736
# 2            4            20               20             2  0.115736
# 3            4            20               20             2  0.115736
# 4            4            20               20             2  0.115736
#
#    threshold  is_safe
# 0         75     True
# 1         75     True
# 2         75     True
# 3         75     True
# 4         75     True
#                   guide         mit         cfd species        accession  \
# 0  AAAAAAAAAACATATTTTGT  100.000000  100.000000  E_coli  GCA_000010385.1
# 1  GGCGGCACAAAAAAAAAAGT   99.851931   99.803364  E_coli  GCA_000010385.1
# 2  CGGCGGGTGATTTCGGTAAA   99.716079   99.477315  E_coli  GCA_000010385.1
# 3  AAAAAAACGTGGCAAAATTA   99.794147   99.741118  E_coli  GCA_000010385.1
# 4  CGATGAAAAAAAAAACGAAC   99.797410   99.876226  E_coli  GCA_000010385.1
#
#    mask_weight  maskset_size  masksubset_size  guideset_num  run_time  \
# 0            6            20               20             3  0.135465
# 1            6            20               20             3  0.135465
# 2            6            20               20             3  0.135465
# 3            6            20               20             3  0.135465
# 4            6            20               20             3  0.135465
#
#    threshold  is_safe
# 0         75     True
# 1         75     True
# 2         75     True
# 3         75     True
# 4         75     True
#                   guide        mit        cfd       species        accession  \
# 0  AAAAAAAAAACATATTTTGT   8.610558  18.442042  X_couchianus  GCF_001444195.1
# 1  GGCGGCACAAAAAAAAAAGT  36.482773  65.687626  X_couchianus  GCF_001444195.1
# 2  CGGCGGGTGATTTCGGTAAA  98.824511  98.717498  X_couchianus  GCF_001444195.1
# 3  AAAAAAACGTGGCAAAATTA  37.889981  61.087574  X_couchianus  GCF_001444195.1
# 4  CGATGAAAAAAAAAACGAAC  48.940061  52.721734  X_couchianus  GCF_001444195.1
#
#    mask_weight  maskset_size  masksubset_size  guideset_num   run_time  \
# 0            8            20               20             1  28.505509
# 1            8            20               20             1  28.505509
# 2            8            20               20             1  28.505509
# 3            8            20               20             1  28.505509
# 4            8            20               20             1  28.505509
#
#    threshold  is_safe
# 0         75    False
# 1         75    False
# 2         75     True
# 3         75    False
# 4         75    False
#                   guide        mit        cfd       species        accession  \
# 0  AAAAAAAAAACATATTTTGT  12.628368  51.671637  X_couchianus  GCF_001444195.1
# 1  GGCGGCACAAAAAAAAAAGT  45.396207  78.901061  X_couchianus  GCF_001444195.1
# 2  CGGCGGGTGATTTCGGTAAA  99.208579  99.307636  X_couchianus  GCF_001444195.1
# 3  AAAAAAACGTGGCAAAATTA  54.262861  80.812924  X_couchianus  GCF_001444195.1
# 4  CGATGAAAAAAAAAACGAAC  62.136870  79.774490  X_couchianus  GCF_001444195.1
#
#    mask_weight  maskset_size  masksubset_size  guideset_num   run_time  \
# 0            4            20               20             2  13.948375
# 1            4            20               20             2  13.948375
# 2            4            20               20             2  13.948375
# 3            4            20               20             2  13.948375
# 4            4            20               20             2  13.948375
#
#    threshold  is_safe
# 0         75    False
# 1         75    False
# 2         75     True
# 3         75    False
# 4         75    False
#                   guide        mit        cfd       species        accession  \
# 0  AAAAAAAAAACATATTTTGT   9.644665  23.468184  X_couchianus  GCF_001444195.1
# 1  GGCGGCACAAAAAAAAAAGT  49.058508  78.407018  X_couchianus  GCF_001444195.1
# 2  CGGCGGGTGATTTCGGTAAA  99.298562  99.052819  X_couchianus  GCF_001444195.1
# 3  AAAAAAACGTGGCAAAATTA  41.487121  65.193456  X_couchianus  GCF_001444195.1
# 4  CGATGAAAAAAAAAACGAAC  54.454994  57.797757  X_couchianus  GCF_001444195.1
#
#    mask_weight  maskset_size  masksubset_size  guideset_num   run_time  \
# 0            6            20               20             3  22.901841
# 1            6            20               20             3  22.901841
# 2            6            20               20             3  22.901841
# 3            6            20               20             3  22.901841
# 4            6            20               20             3  22.901841
#
#    threshold  is_safe
# 0         75    False
# 1         75    False
# 2         75     True
# 3         75    False
# 4         75    False

# %%
# All threshold columns
results = []

for (
    accession,
    guideset_num,
    mask_weight,
    maskset_size,
    threshold
), g in df.groupby([
    'accession',
    'guideset_num',
    'mask_weight',
    'maskset_size',
    'threshold',
]):

    run_time = g['run_time'].iloc[0]

    merged = (
        g[['accession', 'guide', 'threshold']]
        .merge(
            truth[['accession', 'guide', 'threshold']],
            on=['accession', 'guide'],
            how='inner',
            suffixes=('_pred', '_truth')
        )
        .drop_duplicates('guide')
    )

    if merged.empty:
        continue

    pred = merged[f'threshold_pred']
    gt   = merged[f'threshold_truth']

    accuracy = (pred == gt).mean()
    f1 = f1_score(gt, pred)

    tp = ((pred) & (gt)).sum()
    tn = ((~pred) & (~gt)).sum()
    fp = ((pred) & (~gt)).sum()
    fn = ((~pred) & (gt)).sum()

    results.append({
        'accession': accession,
        'guideset_num': guideset_num,
        'mask_weight': mask_weight,
        'maskset_size': maskset_size,
        'threshold': threshold,  # e.g. 75
        'accuracy': accuracy,
        'f1': f1,
        'tp': tp,
        'fp': fp,
        'tn': tn,
        'fn': fn,
        'n_guides': len(merged),
        'offtarget_count': offtarget_counts[accession],
        'offtarget_uniq_counts': offtarget_uniq_counts[accession],
        'run_time': run_time,
    })

df_acc = (
    pd.DataFrame(results)
      .sort_values([
          'accession',
          'guideset_num',
          'mask_weight',
          'maskset_size',
          'threshold'
      ])
)

print(df_acc.head())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 37
#      33
#      34     pred = g[['accession', 'guide', 'threshold']]
#      35     gt   = truth[['accession', 'guide', 'threshold']]
#      36
# ---> 37     accuracy = (pred == gt).mean()
#      38     f1 = f1_score(gt, pred)
#      39
#      40     tp = ((pred) & (gt)).sum()
#
# File ~/venvs/egh490_venv/lib/python3.13/site-packages/pandas/core/ops/common.py:85, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      82     other = sanitize_array(other, None)
#      83     other = ensure_wrapped_if_datetimelike(other)
# ---> 85 return method(self, other)
#
# File ~/venvs/egh490_venv/lib/python3.13/site-packages/pandas/core/arraylike.py:42, in OpsMixin.__eq__(self, other)
#      40 @unpack_zerodim_and_defer("__eq__")
#      41 def __eq__(self, other):
# ---> 42     return self._cmp_method(other, operator.eq)
#
# File ~/venvs/egh490_venv/lib/python3.13/site-packages/pandas/core/frame.py:9123, in DataFrame._cmp_method(self, other, op)
#    9120     def _cmp_method(self, other, op):
#    9121         axis: Literal[1] = 1  # only relevant for Series other case
#    9122
# -> 9123         self, other = self._align_for_op(other, axis, flex=False, level=None)
#    9124
#    9125         # See GH#4537 for discussion of scalar op behavior
#    9126         new_data = self._dispatch_frame_op(other, op, axis=axis)
#
# File ~/venvs/egh490_venv/lib/python3.13/site-packages/pandas/core/frame.py:9437, in DataFrame._align_for_op(self, other, axis, flex, level)
#    9433             if not left._indexed_same(right):
#    9434                 if flex:
#    9435                     left, right = left.align(right, join="outer", level=level)
#    9436                 else:
# -> 9437                     raise ValueError(
#    9438                         "Can only compare identically-labeled (both index and columns) "
#    9439                         "DataFrame objects"
#    9440                     )
#
# ValueError: Can only compare identically-labeled (both index and columns) DataFrame objects

# %%
df_acc.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 df_acc.head()
#
# NameError: name 'df_acc' is not defined

# %%
print(df_acc.to_string())
# Out:
#           accession  guideset_num  mask_weight  maskset_size  threshold  accuracy        f1    tp    fp    tn  fn  n_guides  offtarget_count  offtarget_uniq_counts   run_time
# 0   GCA_000010385.1             1            8            20         75  1.000000  1.000000  9384     0   601   0      9985         860096.0                 834915   0.382605
# 1   GCA_000010385.1             1            8            20         80  1.000000  1.000000  9118     0   867   0      9985         860096.0                 834915   0.382605
# 2   GCA_000010385.1             1            8            20         85  1.000000  1.000000  8606     0  1379   0      9985         860096.0                 834915   0.382605
# 3   GCA_000010385.1             1            8            20         90  1.000000  1.000000  8073     0  1912   0      9985         860096.0                 834915   0.382605
# 4   GCA_000010385.1             1            8            20         95  1.000000  1.000000  7734     0  2251   0      9985         860096.0                 834915   0.382605
# 5   GCA_000010385.1             1            8            20        100  1.000000  0.000000     0     0  9985   0      9985         860096.0                 834915   0.382605
# 6   GCA_000010385.1             2            4            20         75  0.999800  0.999893  9384     2   599   0      9985         860096.0                 834915   0.091318
# 7   GCA_000010385.1             2            4            20         80  0.999599  0.999781  9118     4   863   0      9985         860096.0                 834915   0.091318
# 8   GCA_000010385.1             2            4            20         85  0.999199  0.999535  8606     8  1371   0      9985         860096.0                 834915   0.091318
# 9   GCA_000010385.1             2            4            20         90  0.999299  0.999567  8073     7  1905   0      9985         860096.0                 834915   0.091318
# 10  GCA_000010385.1             2            4            20         95  0.999399  0.999612  7734     6  2245   0      9985         860096.0                 834915   0.091318
# 11  GCA_000010385.1             2            4            20        100  1.000000  0.000000     0     0  9985   0      9985         860096.0                 834915   0.091318
# 12  GCA_000010385.1             3            6            20         75  0.999900  0.999947  9384     1   600   0      9985         860096.0                 834915   0.051349
# 13  GCA_000010385.1             3            6            20         80  0.999900  0.999945  9118     1   866   0      9985         860096.0                 834915   0.051349
# 14  GCA_000010385.1             3            6            20         85  0.999599  0.999768  8606     4  1375   0      9985         860096.0                 834915   0.051349
# 15  GCA_000010385.1             3            6            20         90  0.999800  0.999876  8073     2  1910   0      9985         860096.0                 834915   0.051349
# 16  GCA_000010385.1             3            6            20         95  0.999599  0.999741  7734     4  2247   0      9985         860096.0                 834915   0.051349
# 17  GCA_000010385.1             3            6            20        100  1.000000  0.000000     0     0  9985   0      9985         860096.0                 834915   0.051349
# 18  GCA_000010385.1             4            4            20         75  0.999900  0.999947  9384     1   600   0      9985         860096.0                 834915   0.042995
# 19  GCA_000010385.1             4            4            20         80  0.999800  0.999890  9118     2   865   0      9985         860096.0                 834915   0.042995
# 20  GCA_000010385.1             4            4            20         85  0.999199  0.999535  8606     8  1371   0      9985         860096.0                 834915   0.042995
# 21  GCA_000010385.1             4            4            20         90  0.983676  0.990006  8073   163  1749   0      9985         860096.0                 834915   0.042995
# 22  GCA_000010385.1             4            4            20         95  0.983575  0.989509  7734   164  2087   0      9985         860096.0                 834915   0.042995
# 23  GCA_000010385.1             4            4            20        100  1.000000  0.000000     0     0  9985   0      9985         860096.0                 834915   0.042995
# 24  GCF_001444195.1             1            8            20         75  1.000000  1.000000  9564     0   421   0      9985      101069949.0               89119846  17.166888
# 25  GCF_001444195.1             1            8            20         80  1.000000  1.000000  9263     0   722   0      9985      101069949.0               89119846  17.166888
# 26  GCF_001444195.1             1            8            20         85  1.000000  1.000000  8690     0  1295   0      9985      101069949.0               89119846  17.166888
# 27  GCF_001444195.1             1            8            20         90  1.000000  1.000000  7466     0  2519   0      9985      101069949.0               89119846  17.166888
# 28  GCF_001444195.1             1            8            20         95  1.000000  1.000000  4647     0  5338   0      9985      101069949.0               89119846  17.166888
# 29  GCF_001444195.1             1            8            20        100  1.000000  0.000000     0     0  9985   0      9985      101069949.0               89119846  17.166888
# 30  GCF_001444195.1             2            4            20         75  0.971057  0.985116  9564   289   132   0      9985      101069949.0               89119846  13.161559
# 31  GCF_001444195.1             2            4            20         80  0.949324  0.973413  9263   506   216   0      9985      101069949.0               89119846  13.161559
# 32  GCF_001444195.1             2            4            20         85  0.907962  0.949779  8690   919   376   0      9985      101069949.0               89119846  13.161559
# 33  GCF_001444195.1             2            4            20         90  0.827641  0.896655  7466  1721   798   0      9985      101069949.0               89119846  13.161559
# 34  GCF_001444195.1             2            4            20         95  0.709364  0.762053  4647  2902  2436   0      9985      101069949.0               89119846  13.161559
# 35  GCF_001444195.1             2            4            20        100  1.000000  0.000000     0     0  9985   0      9985      101069949.0               89119846  13.161559
# 36  GCF_001444195.1             3            6            20         75  0.982774  0.991088  9564   172   249   0      9985      101069949.0               89119846  12.456412
# 37  GCF_001444195.1             3            6            20         80  0.970456  0.984326  9263   295   427   0      9985      101069949.0               89119846  12.456412
# 38  GCF_001444195.1             3            6            20         85  0.947221  0.970570  8690   527   768   0      9985      101069949.0               89119846  12.456412
# 39  GCF_001444195.1             3            6            20         90  0.910466  0.943511  7466   894  1625   0      9985      101069949.0               89119846  12.456412
# 40  GCF_001444195.1             3            6            20         95  0.863896  0.872430  4647  1359  3979   0      9985      101069949.0               89119846  12.456412
# 41  GCF_001444195.1             3            6            20        100  1.000000  0.000000     0     0  9985   0      9985      101069949.0               89119846  12.456412
# 42  GCF_001444195.1             4            4            20         75  0.972659  0.985929  9564   273   148   0      9985      101069949.0               89119846   9.343518
# 43  GCF_001444195.1             4            4            20         80  0.953630  0.975617  9263   463   259   0      9985      101069949.0               89119846   9.343518
# 44  GCF_001444195.1             4            4            20         85  0.914972  0.953426  8690   849   446   0      9985      101069949.0               89119846   9.343518
# 45  GCF_001444195.1             4            4            20         90  0.844266  0.905683  7466  1555   964   0      9985      101069949.0               89119846   9.343518
# 46  GCF_001444195.1             4            4            20         95  0.743415  0.783907  4647  2562  2776   0      9985      101069949.0               89119846   9.343518
# 47  GCF_001444195.1             4            4            20        100  1.000000  0.000000     0     0  9985   0      9985      101069949.0               89119846   9.343518

# %%
species = {
    g[1] : g[0]
    for g in genomes
}
species
# Out:
# {'GCA_000010385.1': 'E_coli', 'GCF_001444195.1': 'X_couchianus'}

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay

ACCESSIONS = df_acc['accession'].unique()

WEIGHT = 4

fig, axes = plt.subplots(len(threshold_values), len(ACCESSIONS), figsize=(24, 42))
fig.suptitle("Comparison of perfomance of example 4 mask long\nmask set to the true CRACKLING++ set")

if len(ACCESSIONS) == 1:
    axes = [axes]

for i, accession in enumerate(ACCESSIONS):
    for j, threshold in enumerate(threshold_values):

        row = df_acc[
            (df_acc["accession"] == accession) &
            (df_acc["mask_weight"] == WEIGHT) &
            (df_acc["guideset_num"] == 4) &
            (df_acc["threshold"] == threshold)
        ].iloc[0]
    
        accuracy = row["f1"]
    
        cm = np.array([
            [row['tp'], row['fn']],
            [row['fp'], row['tn']]
        ])
        
        disp = ConfusionMatrixDisplay(
            confusion_matrix=cm,
            display_labels=['Safe', 'Unsafe']
        )
    
        disp.plot(ax=axes[j, i], values_format='d', colorbar=False)
        
        disp.ax_.set(
            xlabel='New (Predicted)',
            ylabel='CRACKLING++ (True)'
        )
        
        axes[j, i].set_title(
            f"{species[accession]}\nThreshold {threshold}"
        )

plt.tight_layout()
plt.savefig("accuracy.png")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay

ACCESSIONS = df_acc['accession'].unique()



WEIGHT = 9

# fig, axes = plt.subplots(1, len(ACCESSIONS), figsize=(18, 7))
fig, axes = plt.subplots(figsize=(18, 7))
fig.suptitle("Perfomance comparision of the generated 9-mask long\nset to the true CRACKLING++ set")

if len(ACCESSIONS) == 1:
    axes = [axes]

for i, accession in enumerate(ACCESSIONS):

    if accession != "GCA_003400415.2":
        continue

    row = df_acc[
        (df_acc["accession"] == accession) &
        (df_acc["mask_weight"] == WEIGHT)
    ].iloc[0]

    accuracy = row["f1"]

    cm = np.array([
        [row['tp'], row['fn']],
        [row['fp'], row['tn']]
    ])
    
    disp = ConfusionMatrixDisplay(
        confusion_matrix=cm,
        display_labels=['Safe', 'Unsafe']
    )

    disp.plot(ax=axes, values_format='d', colorbar=False)
    disp.ax_.set(xlabel='New (Predicted)', ylabel='CRACKLING++ (True)')

    # axes.set_title(
    #     f"{accession} - {species[accession]}"
    # )

plt.tight_layout()
plt.savefig("accuracy.png")
plt.show()

# %% [markdown]
# ### Plot: Number of safe/unsafe per genome (using 8-28-28)

# %%
fig, ax = plt.subplots(figsize=(10, 6))

d = df_acc[df_acc['masksubset_size'] == 28][['accession', 'tp', 'tn', 'offtarget_count']].sort_values('offtarget_count')

d.plot.bar(x='accession', y=['tp', 'tn'], stacked=True, ax=ax, color=CLASS_COLOURS)

ax.set_xticklabels([acc_label[x] for x in d['accession']], rotation=45, ha='right')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[48], line 5
#       1 fig, ax = plt.subplots(figsize=(10, 6))
#       2
#       3 d = df_acc[df_acc['masksubset_size'] == 28][['accession', 'tp', 'tn', 'offtarget_count']].sort_values('offtarget_count')
#       4
# ----> 5 d.plot.bar(x='accession', y=['tp', 'tn'], stacked=True, ax=ax, color=CLASS_COLOURS)
#       6
#       7 ax.set_xticklabels([acc_label[x] for x in d['accession']], rotation=45, ha='right')
#
# File ~/venvs/egh490_venv/lib/python3.13/site-packages/pandas/plotting/_core.py:1432, in PlotAccessor.bar(self, x, y, color, **kwargs)
#    1430 if color is not None:
#    1431     kwargs["color"] = color
# -> 1432 return self(kind="bar", x=x, y=y, **kwargs)
#
# File ~/venvs/egh490_venv/lib/python3.13/site-packages/pandas/plotting/_core.py:1185, in PlotAccessor.__call__(self, *args, **kwargs)
#    1182             label_name = label_kw or data.columns
#    1183             data.columns = label_name
# -> 1185 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~/venvs/egh490_venv/lib/python3.13/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plt.draw_if_interactive()
#      73 return plot_obj.result
#
# File ~/venvs/egh490_venv/lib/python3.13/site-packages/pandas/plotting/_matplotlib/core.py:525, in MPLPlot.generate(self)
#     523 for ax in self.axes:
#     524     self._post_plot_logic_common(ax)
# --> 525     self._post_plot_logic(ax, self.data)
#
# File ~/venvs/egh490_venv/lib/python3.13/site-packages/pandas/plotting/_matplotlib/core.py:2049, in BarPlot._post_plot_logic(self, ax, data)
#    2046 else:
#    2047     str_index = [pprint_thing(key) for key in range(data.shape[0])]
# -> 2049 s_edge = self.ax_pos[0] - 0.25 + self.lim_offset
#    2050 e_edge = self.ax_pos[-1] + 0.25 + self.bar_width + self.lim_offset
#    2052 self._decorate_ticks(ax, self._get_index_name(), str_index, s_edge, e_edge)
#
# IndexError: index 0 is out of bounds for axis 0 with size 0
